# %%
# Importing necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
data=pd.read_csv("Code4_Zscaled29.csv",index_col = 0)
data.head()
# Out:
#    record  dayssince_fulladdress  vel_fulladdress_30  vel_fulladdress_14  \
# 0       1               0.294021           -0.101958           -0.079045
# 1       2               0.294021           -0.101958           -0.079045
# 2       3               0.294021           -0.101958           -0.079045
# 3       4               0.294021           -0.101958           -0.079045
# 4       5               0.294021           -0.101958           -0.079045
#
#    vel_fulladdress_7  vel_fulladdress_3  relv_fulladdress_14  \
# 0          -0.067094          -0.057932             -0.06999
# 1          -0.067094          -0.057932             -0.06999
# 2          -0.067094          -0.057932             -0.06999
# 3          -0.067094          -0.057932             -0.06999
# 4          -0.067094          -0.057932             -0.06999
#
#    relv_fulladdress_30  relv_fulladdress_60  vel_fulladdress_1  ...  \
# 0            -0.069649            -0.069424          -0.049665  ...
# ...

# %%
data2 = pd.read_csv("application.csv",index_col = 0)
data2 = data2.reset_index()

# %%
data['date'] = data2['date'].astype(str)
data['date'] = pd.to_datetime(data['date'])
data.head()
# Out:
#    record  dayssince_fulladdress  vel_fulladdress_30  vel_fulladdress_14  \
# 0       1               0.294021           -0.101958           -0.079045
# 1       2               0.294021           -0.101958           -0.079045
# 2       3               0.294021           -0.101958           -0.079045
# 3       4               0.294021           -0.101958           -0.079045
# 4       5               0.294021           -0.101958           -0.079045
#
#    vel_fulladdress_7  vel_fulladdress_3  relv_fulladdress_14  \
# 0          -0.067094          -0.057932             -0.06999
# 1          -0.067094          -0.057932             -0.06999
# 2          -0.067094          -0.057932             -0.06999
# 3          -0.067094          -0.057932             -0.06999
# 4          -0.067094          -0.057932             -0.06999
#
#    relv_fulladdress_30  relv_fulladdress_60  vel_fulladdress_1  ...  \
# 0            -0.069649            -0.069424          -0.049665  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 0 to 999999
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   record                      1000000 non-null  int64
#  1   dayssince_fulladdress       1000000 non-null  float64
#  2   vel_fulladdress_30          1000000 non-null  float64
#  3   vel_fulladdress_14          1000000 non-null  float64
#  4   vel_fulladdress_7           1000000 non-null  float64
#  5   vel_fulladdress_3           1000000 non-null  float64
#  6   relv_fulladdress_14         1000000 non-null  float64
#  7   relv_fulladdress_30         1000000 non-null  float64
#  8   relv_fulladdress_60         1000000 non-null  float64
#  9   vel_fulladdress_1           1000000 non-null  float64
#  10  dayssince_fulladdressphone  1000000 non-null  float64
#  11  vel_fulladdressphone_30     1000000 non-null  float64
# ...

# %%
train = data[data.date < '2016-11-01']

test = data[data.date >= '2016-11-01']

# %%
train.shape
# Out:
# (833507, 30)

# %%
train.head()
# Out:
#    record  dayssince_fulladdress  vel_fulladdress_30  vel_fulladdress_14  \
# 0       1               0.294021           -0.101958           -0.079045
# 1       2               0.294021           -0.101958           -0.079045
# 2       3               0.294021           -0.101958           -0.079045
# 3       4               0.294021           -0.101958           -0.079045
# 4       5               0.294021           -0.101958           -0.079045
#
#    vel_fulladdress_7  vel_fulladdress_3  relv_fulladdress_14  \
# 0          -0.067094          -0.057932             -0.06999
# 1          -0.067094          -0.057932             -0.06999
# 2          -0.067094          -0.057932             -0.06999
# 3          -0.067094          -0.057932             -0.06999
# 4          -0.067094          -0.057932             -0.06999
#
#    relv_fulladdress_30  relv_fulladdress_60  vel_fulladdress_1  ...  \
# 0            -0.069649            -0.069424          -0.049665  ...
# ...

# %%
test.shape
# Out:
# (166493, 30)

# %%
test.head()
# Out:
#         record  dayssince_fulladdress  vel_fulladdress_30  vel_fulladdress_14  \
# 833507  833508              -2.005877           -0.101958           -0.079045
# 833508  833509               0.294021           -0.101958           -0.079045
# 833509  833510               0.537280            1.475749            1.568788
# 833510  833511               0.294021           -0.101958           -0.079045
# 833511  833512               0.294021           -0.101958           -0.079045
#
#         vel_fulladdress_7  vel_fulladdress_3  relv_fulladdress_14  \
# 833507          -0.067094          -0.057932             -0.06999
# 833508          -0.067094          -0.057932             -0.06999
# 833509          -0.067094          -0.057932             -0.06999
# 833510          -0.067094          -0.057932             -0.06999
# 833511          -0.067094          -0.057932             -0.06999
#
#         relv_fulladdress_30  relv_fulladdress_60  vel_fulladdress_1  ...  \
# ...

# %%
train.drop('date',axis = 1,inplace = True)
test.drop('date',axis = 1,inplace = True)
test
# Out:
# C:\Users\jayan\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3994: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          record  dayssince_fulladdress  vel_fulladdress_30  \
# 833507   833508              -2.005877           -0.101958
# 833508   833509               0.294021           -0.101958
# 833509   833510               0.537280            1.475749
# 833510   833511               0.294021           -0.101958
# 833511   833512               0.294021           -0.101958
# ...         ...                    ...                 ...
# 999995   999996               0.294021           -0.101958
# 999996   999997               0.294021           -0.101958
# 999997   999998               0.294021           -0.101958
# ...

# %%
train.to_csv("traintest.csv")

# %%
test.to_csv("oot.csv")
